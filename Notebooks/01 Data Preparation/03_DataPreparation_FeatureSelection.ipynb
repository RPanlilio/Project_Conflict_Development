# %% [markdown]
# # Data Preparation: Feature Selection

# %% [markdown]
# ## Import Libraries

# %%
# Import Required Modules and Packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import sys

from sklearn.feature_selection import VarianceThreshold

# %%
cd
# Out:
# /root

# %% [markdown]
# ## Load Data

# %%
# Upload the Final Data
final_data = pd.read_csv('Project/Cleaned/final_data.csv', na_values = ['..'])
final_data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %% [markdown]
# ## Feature Selection

# %%
# Randomly Select 1000 Observation
#final_data = final_data.sample(n = 1000) 
#final_data = final_data.reset_index(drop=True)

# %%
# Country-Year, Features, Outcome Data
final_data_country_year = final_data.iloc[0:,:2]
final_data_features = final_data.iloc[0:,2:-14]
final_data_outcome = final_data.iloc[0:,-14:]

# %%
# Dropping Features with High Correlation
correlated_features = set()
correlation_matrix = final_data_features.corr()

for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            correlated_features.add(colname)
final_data_features.drop(labels=correlated_features, axis=1, inplace=True)

print('Number of Correlated Features: ', len(correlated_features))
print("Shape of Data (Final): ",final_data_features.shape)
# Out:
# Number of Correlated Features:  685
# Shape of Data (Final):  (4992, 740)

# %%
final_data_features.head()
# Out:
#    AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  AG.LND.AGRI.K2  \
# 0           110.0                NaN             NaN        377900.0
# 1           110.0                NaN             NaN        378670.0
# 2           110.0                NaN             NaN        377530.0
# 3           110.0                NaN             NaN        377530.0
# 4           110.0                NaN             NaN        377530.0
#
#    AG.LND.AGRI.ZS  AG.LND.ARBL.HA.PC  AG.LND.ARBL.ZS  AG.LND.CROP.ZS  \
# 0       57.883773           0.397011       11.771283        0.160831
# 1       58.001716           0.393003       11.881567        0.168489
# 2       57.827099           0.379409       11.722268        0.153172
# 3       57.827099           0.369731       11.768220        0.107221
# 4       57.827099           0.355579       11.768220        0.107221
#
#    AG.LND.EL5M.RU.K2  AG.LND.EL5M.RU.ZS  ...  per_allsp.ben_q1_tot  \
# 0                NaN                NaN  ...                   NaN
# 1                NaN                NaN  ...                   NaN
# 2                NaN                NaN  ...                   NaN
# 3                NaN                NaN  ...                   NaN
# 4                NaN                NaN  ...                   NaN
#
#    per_allsp.cov_pop_tot  per_lm_alllm.adq_pop_tot  per_lm_alllm.ben_q1_tot  \
# 0                    NaN                       NaN                      NaN
# 1                    NaN                       NaN                      NaN
# 2                    NaN                       NaN                      NaN
# 3                    NaN                       NaN                      NaN
# 4                    NaN                       NaN                      NaN
#
#    per_lm_alllm.cov_pop_tot  per_sa_allsa.adq_pop_tot  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    per_sa_allsa.ben_q1_tot  per_sa_allsa.cov_pop_tot  per_si_allsi.ben_q1_tot  \
# 0                      NaN                       NaN                      NaN
# 1                      NaN                       NaN                      NaN
# 2                      NaN                       NaN                      NaN
# 3                      NaN                       NaN                      NaN
# 4                      NaN                       NaN                      NaN
#
#    per_si_allsi.cov_pop_tot
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 740 columns]

# %%
# Removing Columns with Low Variance
selector = VarianceThreshold(threshold=.5)
selector.fit(final_data_features)
final_data_features = final_data_features[final_data_features.columns[selector.get_support(indices=True)]]

print("Shape of Data (Final): ", final_data_features.shape)
# Out:
# Shape of Data (Final):  (4992, 714)

# %%
# Removing Columns with More than 20% missing values
threshold = len(final_data_features) * .2
final_data_features.dropna(thresh = threshold, axis = 1, inplace = True)
final_data_features = final_data_features.fillna(final_data_features.mean())

print("Shape of Data (Final): ",final_data_features.shape)
# Out:
# Shape of Data (Final):  (4992, 714)

# %%
# Final Cleaned and Processed Dataset
final_data_features = final_data_features.astype(int)
final_data_outcome = final_data_outcome.astype(float)
final_data = pd.concat([final_data_country_year, final_data_features], axis=1)
final_data = pd.concat([final_data, final_data_outcome], axis=1)

# Set Indices
final_data = final_data.set_index(['country', 'year'])
final_data
# Out:
#                     AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  AG.CON.FERT.ZS  \
# country     year
# Afghanistan 1997.0             110               3436             432
#             1998.0             110               3436             432
#             1999.0             110               3436             432
#             2000.0             110               3436             432
#             2001.0             110               3436             432
# ...                            ...                ...             ...
# Zimbabwe    2015.0           22496                144              22
#             2016.0           22496                144              22
#             2017.0           22496                144              22
#             2018.0           22496                144              22
#             2019.0           22496                144              22
#
#                     AG.LND.AGRI.K2  AG.LND.AGRI.ZS  AG.LND.ARBL.ZS  \
# country     year
# Afghanistan 1997.0          377900              57              11
#             1998.0          378670              58              11
#             1999.0          377530              57              11
#             2000.0          377530              57              11
#             2001.0          377530              57              11
# ...                            ...             ...             ...
# Zimbabwe    2015.0          162000              41              10
#             2016.0          162000              41              10
#             2017.0          162000              41              10
#             2018.0          162000              41              10
#             2019.0          162000              41              10
#
#                     AG.LND.CROP.ZS  AG.LND.EL5M.RU.K2  AG.LND.EL5M.RU.ZS  \
# country     year
# Afghanistan 1997.0               0               6642                  4
#             1998.0               0               6642                  4
#             1999.0               0               6642                  4
#             2000.0               0               6642                  4
#             2001.0               0               6642                  4
# ...                            ...                ...                ...
# Zimbabwe    2015.0               0               1597                  0
#             2016.0               0               1597                  0
#             2017.0               0               1597                  0
#             2018.0               0               1597                  0
#             2019.0               0               1597                  0
#
#                     AG.LND.EL5M.UR.K2  ...  conflict_instances_event_5  \
# country     year                       ...
# Afghanistan 1997.0                673  ...                         0.0
#             1998.0                673  ...                         0.0
#             1999.0                673  ...                         0.0
#             2000.0                673  ...                         0.0
#             2001.0                673  ...                         0.0
# ...                               ...  ...                         ...
# Zimbabwe    2015.0                125  ...                         6.0
#             2016.0                125  ...                        14.0
#             2017.0                125  ...                        15.0
#             2018.0                125  ...                        19.0
#             2019.0                125  ...                        10.0
#
#                     conflict_instances_event_6  conflict_fatalities_event_1  \
# country     year
# Afghanistan 1997.0                         0.0                          0.0
#             1998.0                         0.0                          0.0
#             1999.0                         0.0                          0.0
#             2000.0                         0.0                          0.0
#             2001.0                         0.0                          0.0
# ...                                        ...                          ...
# Zimbabwe    2015.0                        97.0                          0.0
#             2016.0                        72.0                          0.0
#             2017.0                       151.0                          5.0
#             2018.0                       153.0                          5.0
#             2019.0                        63.0                          4.0
#
#                     conflict_fatalities_event_2  conflict_fatalities_event_3  \
# country     year
# Afghanistan 1997.0                          0.0                          0.0
#             1998.0                          0.0                          0.0
#             1999.0                          0.0                          0.0
#             2000.0                          0.0                          0.0
#             2001.0                          0.0                          0.0
# ...                                         ...                          ...
# Zimbabwe    2015.0                          0.0                          0.0
#             2016.0                          0.0                          0.0
#             2017.0                          0.0                          0.0
#             2018.0                          2.0                          0.0
#             2019.0                          0.0                          0.0
#
#                     conflict_fatalities_event_4  conflict_fatalities_event_5  \
# country     year
# Afghanistan 1997.0                          0.0                          0.0
#             1998.0                          0.0                          0.0
#             1999.0                          0.0                          0.0
#             2000.0                          0.0                          0.0
#             2001.0                          0.0                          0.0
# ...                                         ...                          ...
# Zimbabwe    2015.0                         12.0                          0.0
#             2016.0                          0.0                          0.0
#             2017.0                          2.0                          0.0
#             2018.0                         10.0                          0.0
#             2019.0                         16.0                          0.0
#
#                     conflict_fatalities_event_6  conflict_instances_total  \
# country     year
# Afghanistan 1997.0                          0.0                       0.0
#             1998.0                          0.0                       0.0
#             1999.0                          0.0                       0.0
#             2000.0                          0.0                       0.0
#             2001.0                          0.0                       0.0
# ...                                         ...                       ...
# Zimbabwe    2015.0                          7.0                     264.0
#             2016.0                          6.0                     228.0
#             2017.0                          2.0                     298.0
#             2018.0                          7.0                     344.0
#             2019.0                         16.0                     175.0
#
#                     conflict_fatalities_total
# country     year
# Afghanistan 1997.0                        0.0
#             1998.0                        0.0
#             1999.0                        0.0
#             2000.0                        0.0
#             2001.0                        0.0
# ...                                       ...
# Zimbabwe    2015.0                       19.0
#             2016.0                        6.0
#             2017.0                        9.0
#             2018.0                       24.0
#             2019.0                       36.0
#
# [4992 rows x 728 columns]

# %%
# Shape of Data
print("Shape of Data (Final): ", final_data.shape)
# Out:
# Shape of Data (Final):  (4992, 728)

# %% [markdown]
# ## Save Pre-processed Data

# %%
# Save Data
final_data.to_csv('Project/Cleaned/final_data_preprocessed.csv')
